# %%
#imports
import numpy as np
import pandas as pd
import geopandas as gpd
import json

from shapely.geometry import Point

import matplotlib.pyplot as plt

from bokeh.io import show, output_notebook, output_file
from bokeh.plotting import save, figure
from bokeh.models import GeoJSONDataSource, HoverTool, LinearColorMapper

#library that can look up FIPS codes
import us

# %matplotlib inline

# %%
gdf = gpd.read_file('./data/district_shape_files/us-116th-congressional-districts.shp')

# %%
gdf.head()
# Out:
#        AREALAND       CENTLON                           BASENAME FUNCSTAT  \
# 0  1.961857e+09  -094.7924812                                  3        N
# 1  3.707606e+10  -097.7398849                                  4        N
# 2  3.663340e+10  -095.4308232                                  2        N
# 3  1.963470e+11  -100.2270268  Congressional District (at Large)        N
# 4  5.435558e+08  +144.7693797       Delegate District (at Large)        N
#
#   CDTYP      CENTLAT CDSESSN  MTFCC     INTPTLAT HU100  \
# 0     O  +38.8921109     116  G5200  +38.8950035  None
# 1     O  +37.5477516     116  G5200  +37.5544654  None
# 2     O  +38.4777375     116  G5200  +38.4822777  None
# 3     O  +44.4445678     116  G5200  +44.4467957  None
# 4     O  +13.4427156     116  G5200  +13.4382886  None
#
#                          ...                              INTPTLON LSADC  \
# 0                        ...                          -094.7906431    C2
# 1                        ...                          -097.7439831    C2
# 2                        ...                          -095.4246400    C2
# 3                        ...                          -100.2381762    C1
# 4                        ...                          +144.7729493    C4
#
#   POP100 STATE GEOID                               NAME           OID  \
# 0   None    20  2003           Congressional District 3  2.119047e+14
# 1   None    20  2004           Congressional District 4  2.119047e+14
# 2   None    20  2002           Congressional District 2  2.119047e+14
# 3   None    46  4600  Congressional District (at Large)  2.119047e+14
# 4   None    66  6698       Delegate District (at Large)  2.119047e+14
#
#             LEN  CD116                                           geometry
# 0  3.007789e+05     03  POLYGON ((-10581640.8426 4716558.141000003, -1...
# 1  1.361146e+06     04  POLYGON ((-11084143.3693 4554917.087099999, -1...
# 2  1.481857e+06     02  POLYGON ((-10776468.3192 4830390.271700002, -1...
# 3  2.963038e+06     00  POLYGON ((-11583670.1033 5621144.450300001, -1...
# 4  1.792114e+05     98  POLYGON ((16092726.9697 1510969.434599999, 160...
#
# [5 rows x 21 columns]

# %%
#just the states, not the territories
gdf = gdf[gdf.STATE.astype(int) <59]

# %%
#getting rid of undefined congressional districts
gdf = gdf[gdf.CD116 != 'ZZ']

# %%
#getting rid of DC
gdf = gdf[gdf.CD116 != '98']

# %%
#making dictionary of state codes
state_codes = {}

for i in gdf.STATE:
    state = us.states.lookup(i)
    state_codes[i] = state.abbr

# %%
#mapping dictionary of state codes to the state column
gdf.STATE = gdf.STATE.map(state_codes)

# %%
#changing at-large districts to 01
gdf.CD116 = np.where(gdf.CD116 == '00','01', gdf.CD116)

# %%
##making new district column
gdf['district'] = gdf.STATE + '-' + gdf.CD116

# %%
gdf.district.nunique()
# Out:
# 435

# %%
#resetting index
gdf.reset_index(drop=True, inplace=True)

# %%
gdf.head()
# Out:
#        AREALAND       CENTLON                           BASENAME FUNCSTAT  \
# 0  1.961857e+09  -094.7924812                                  3        N
# 1  3.707606e+10  -097.7398849                                  4        N
# 2  3.663340e+10  -095.4308232                                  2        N
# 3  1.963470e+11  -100.2270268  Congressional District (at Large)        N
# 4  6.086782e+09  -072.8559714                                  1        N
#
#   CDTYP      CENTLAT CDSESSN  MTFCC     INTPTLAT HU100   ...     LSADC POP100  \
# 0     O  +38.8921109     116  G5200  +38.8950035  None   ...        C2   None
# 1     O  +37.5477516     116  G5200  +37.5544654  None   ...        C2   None
# 2     O  +38.4777375     116  G5200  +38.4822777  None   ...        C2   None
# 3     O  +44.4445678     116  G5200  +44.4467957  None   ...        C1   None
# 4     O  +42.3220872     116  G5200  +42.3310441  None   ...        C2   None
#
#   STATE GEOID                               NAME           OID           LEN  \
# 0    KS  2003           Congressional District 3  2.119047e+14  3.007789e+05
# 1    KS  2004           Congressional District 4  2.119047e+14  1.361146e+06
# 2    KS  2002           Congressional District 2  2.119047e+14  1.481857e+06
# 3    SD  4600  Congressional District (at Large)  2.119047e+14  2.963038e+06
# 4    MA  2501           Congressional District 1  2.119047e+14  6.792394e+05
#
#    CD116                                           geometry district
# 0     03  POLYGON ((-10581640.8426 4716558.141000003, -1...    KS-03
# 1     04  POLYGON ((-11084143.3693 4554917.087099999, -1...    KS-04
# 2     02  POLYGON ((-10776468.3192 4830390.271700002, -1...    KS-02
# 3     01  POLYGON ((-11583670.1033 5621144.450300001, -1...    SD-01
# 4     01  POLYGON ((-8182896.5063 5173890.644599997, -81...    MA-01
#
# [5 rows x 22 columns]

# %%
#drop columns
gdf.drop(columns=['AREALAND','CENTLON','BASENAME','FUNCSTAT','CDTYP',
                  'HU100','POP100','GEOID','MTFCC','INTPTLON','LSADC',
                  'NAME','OID','LEN'],
        inplace=True)

# %%
gdf.head()
# Out:
#        CENTLAT CDSESSN     INTPTLAT          AREA STATE CD116  \
# 0  +38.8921109     116  +38.8950035  3.297382e+09    KS    03
# 1  +37.5477516     116  +37.5544654  5.938341e+10    KS    04
# 2  +38.4777375     116  +38.4822777  6.076966e+10    KS    02
# 3  +44.4445678     116  +44.4467957  3.919818e+11    SD    01
# 4  +42.3220872     116  +42.3310441  1.137912e+10    MA    01
#
#                                             geometry district
# 0  POLYGON ((-10581640.8426 4716558.141000003, -1...    KS-03
# 1  POLYGON ((-11084143.3693 4554917.087099999, -1...    KS-04
# 2  POLYGON ((-10776468.3192 4830390.271700002, -1...    KS-02
# 3  POLYGON ((-11583670.1033 5621144.450300001, -1...    SD-01
# 4  POLYGON ((-8182896.5063 5173890.644599997, -81...    MA-01

# %% [markdown]
# ## Testing

# %%
final_df = pd.read_csv('./data/final_df.csv')

# %%
final_df.drop(columns = 'Unnamed: 0',inplace=True)

# %%
final_df.head()
# Out:
#   district  uncontested 116first   116last  116gender 116party  2018votes  \
# 0    AL-01        False  Bradley     Byrne          1        R     152308
# 1    AL-02        False   Martha      Roby          0        R     138582
# 2    AL-03        False     Mike    Rogers          1        R     147481
# 3    AL-04        False   Robert  Aderholt          1        R     183968
# 4    AL-05        False       Mo    Brooks          1        R     158373
#
#    2018pct  2018margin  congress    ...     trumpagree_20 ypreds_-20  \
# 0     63.3        26.6       115    ...          1.150000  37.746425
# 1     61.5        23.0       115    ...          1.149474  37.746425
# 2     63.8        27.6       115    ...          1.150000  38.554546
# 3     79.9        59.8       115    ...          1.162105  37.746425
# 4     61.1        22.2       115    ...          1.004348  37.746425
#
#    ypreds_-15  ypreds_-10  ypreds_-5   ypreds_0   ypreds_5  ypreds_10  \
# 0   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 1   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 2   38.554546   38.686064  38.686064  38.686064  38.686064  39.679659
# 3   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 4   37.746425   37.746425  37.746425  37.746425  37.877942  37.877942
#
#    ypreds_15  ypreds_20
# 0  38.871538  38.871538
# 1  38.871538  38.871538
# 2  39.679659  39.679659
# 3  38.871538  38.871538
# 4  37.877942  37.877942
#
# [5 rows x 34 columns]

# %%
final_df['115agree_pct'] = final_df['115agree_pct'] * 100

# %%
final_df.head()
# Out:
#   district  uncontested 116first   116last  116gender 116party  2018votes  \
# 0    AL-01        False  Bradley     Byrne          1        R     152308
# 1    AL-02        False   Martha      Roby          0        R     138582
# 2    AL-03        False     Mike    Rogers          1        R     147481
# 3    AL-04        False   Robert  Aderholt          1        R     183968
# 4    AL-05        False       Mo    Brooks          1        R     158373
#
#    2018pct  2018margin  congress    ...     trumpagree_20 ypreds_-20  \
# 0     63.3        26.6       115    ...          1.150000  37.746425
# 1     61.5        23.0       115    ...          1.149474  37.746425
# 2     63.8        27.6       115    ...          1.150000  38.554546
# 3     79.9        59.8       115    ...          1.162105  37.746425
# 4     61.1        22.2       115    ...          1.004348  37.746425
#
#    ypreds_-15  ypreds_-10  ypreds_-5   ypreds_0   ypreds_5  ypreds_10  \
# 0   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 1   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 2   38.554546   38.686064  38.686064  38.686064  38.686064  39.679659
# 3   37.746425   37.877942  37.877942  37.877942  37.877942  38.871538
# 4   37.746425   37.746425  37.746425  37.746425  37.877942  37.877942
#
#    ypreds_15  ypreds_20
# 0  38.871538  38.871538
# 1  38.871538  38.871538
# 2  39.679659  39.679659
# 3  38.871538  38.871538
# 4  37.877942  37.877942
#
# [5 rows x 34 columns]

# %%
merged = gdf.merge(final_df, on='district')

# %%
merged_json = json.loads(merged.to_json())

json_data = json.dumps(merged_json)

# %% [markdown]
# ## Bokeh for Trump Agreement Percentage

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

# %%
#input GeoJSON data
geosource = GeoJSONDataSource(geojson = json_data)

#make color palette
palette = brewer['RdBu'][11]

#instantiate colors on a linear scale
color_mapper = LinearColorMapper(palette = palette, low = 0, high = 100)

#x-tick labels for legend
tick_labels = {'5': '<5%', '10':'10%', '15':'15%','20':'20%',
               '75':'75%', '80':'80%','85':'85%', '90': '90%', '95': '>95%'}

#create the color bar
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

#create plot
p = figure(title = 'Trump Agreement Percentage', plot_height = 600 , plot_width = 950,
           toolbar_location = 'right',
           tooltips=[("Name", "@district"), ("Trump Agreement %", "@115agree_pct"),('Congressman','@115last'),('Party','@115party')],
           x_axis_location=None, y_axis_location=None,)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

#add the data patches
p.patches('xs','ys', source = geosource,fill_color = {'field' :'115agree_pct', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)

#put the legend below
p.add_layout(color_bar, 'below')

# %%
save(p, '/Users/christophershaw/Desktop/DSI/capstone/trump_agreement_districts.html',title='Trump Agreement by District')
# Out:
# /anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:123: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# '/Users/christophershaw/Desktop/DSI/capstone/trump_agreement_districts.html'

# %% [markdown]
# ## Bokeh for 2018 Margin

# %%
geosource = GeoJSONDataSource(geojson = json_data)

palette = brewer['RdBu'][11]

color_mapper = LinearColorMapper(palette = palette, low = -10, high = 10)

tick_labels = {'-10':'>-10%','-8':'-8%','-6':'-6%','-4':'-4%','-2':'-2%','0': '<2%', 
               '2':'2%', '4':'4%','6':'6%', '8': '8%','10': '>10%'}

color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

p = figure(title = '2018 Vote Margin', plot_height = 600 , plot_width = 950,
           toolbar_location = 'right',
           tooltips=[("Name", "@district"), ("2018 Election Margin", "@2018margin"),
                     ('Congressman','@116last'),('Party','@116party'),('Uncontested','@uncontested')],
           x_axis_location=None, y_axis_location=None,)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

p.patches('xs','ys', source = geosource,fill_color = {'field' :'2018margin', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)

p.add_layout(color_bar, 'below')

# %%
save(p, '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts.html',title='2018 Election Margins')
# Out:
# /anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:123: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts.html'

# %% [markdown]
# ## Predicted Margin with 10% more agreement with Trump

# %%
geosource = GeoJSONDataSource(geojson = json_data)

palette = brewer['RdBu'][11]

color_mapper = LinearColorMapper(palette = palette, low = -10, high = 10)

tick_labels = {'-10':'>-10%','-8':'-8%','-6':'-6%','-4':'-4%','-2':'-2%','0': '<2%', 
               '2':'2%', '4':'4%','6':'6%', '8': '8%','10': '>10%'}

color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

p = figure(title = '2018 Vote Margin +10% Agreement', plot_height = 600 , plot_width = 950,
           toolbar_location = 'right',
           tooltips=[("Name", "@district"), ("2018 Election Margin", "@ypreds_10"),
                     ('Party','@116party')],
           x_axis_location=None, y_axis_location=None,)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

p.patches('xs','ys', source = geosource,fill_color = {'field' :'ypreds_10', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)

p.add_layout(color_bar, 'below')

# %%
save(p, '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts_10.html',title='2018 Election Margins +10% Agreement')
# Out:
# /anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:123: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts_10.html'

# %% [markdown]
# ## Predicted Margin with 10% less agreement with Trump

# %%
#renaming negative columns for plotting purposes
final_df.rename(columns={'ypreds_-10':'ypreds_minus10'},inplace=True)

# %%
merged = gdf.merge(final_df, on='district')

merged_json = json.loads(merged.to_json())

json_data = json.dumps(merged_json)

# %%
geosource = GeoJSONDataSource(geojson = json_data)

palette = brewer['RdBu'][11]

color_mapper = LinearColorMapper(palette = palette, low = -10, high = 10)

tick_labels = {'-10':'>-10%','-8':'-8%','-6':'-6%','-4':'-4%','-2':'-2%','0': '<2%', 
               '2':'2%', '4':'4%','6':'6%', '8': '8%','10': '>10%'}

color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

p = figure(title = '2018 Vote Margin -10% Agreement', plot_height = 600 , plot_width = 950,
           toolbar_location = 'right',
           tooltips=[("Name", "@district"), ("2018 Election Margin", "@ypreds_minus10"),
                     ('Party','@116party')],
           x_axis_location=None, y_axis_location=None,)

p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

p.patches('xs','ys', source = geosource,fill_color = {'field' :'ypreds_minus10', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)

p.add_layout(color_bar, 'below')

# %%
save(p, '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts_-10.html',title='2018 Election Margins -10% Agreement')
# Out:
# /anaconda3/lib/python3.7/site-packages/bokeh/io/saving.py:123: UserWarning: save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN
#   warn("save() called but no resources were supplied and output_file(...) was never called, defaulting to resources.CDN")
# '/Users/christophershaw/Desktop/DSI/capstone/2018margin_districts_-10.html'
